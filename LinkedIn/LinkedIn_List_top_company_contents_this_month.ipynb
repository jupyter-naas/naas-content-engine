# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # LinkedIn - List top company contents
# <a href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/LinkedIn/Linkedin_Follow_number_of_content_published.ipynb" target="_parent"><img src="https://naasai-public.s3.eu-west-3.amazonaws.com/open_in_naas.svg"/></a>

# %% [markdown]
# **Tags:** #linkedin #html #plotly #csv #image #content #analytics #automation

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# ## Input

# %%
# Except allow to run common.ipynb once using Naas Engine
try:
    # %run "../common.ipynb"
except:
    # %run "common.ipynb"

# %% [markdown]
# ### Setup Variables

# %%
KPI_TITLE = "Top posts"
INPUT_DATABASE = LK_COMPANY_POSTS
OWNER = LK_COMPANY_NAME
OWNER_ID = LK_COMPANY_ID
PLATFORM = LINKEDIN
LOGO = LINKEDIN_LOGO
COLOR = LINKEDIN_COLOR

# %% [markdown]
# ### Setup Constants

# %%
# Inputs
SCENARIO = SCENARIO_MTD
PERIOD = PERIOD_MTD
PERIOD_D = DISPLAY_MTD
PERIOD_TEXT = TEXT_MTD
PERIOD_TEXT2 = TEXT2_MTD

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get your posts

# %%
df_posts = get_data(INPUT_DATABASE)
print("✅ Posts fetched:", len(df_posts))
df_posts.head(1)
# Out:
# ✅ Posts fetched: 126
#            ACTIVITY_ID             PUBLISHED_DATE AUTHOR_NAME  \
# 0  6946860124556681216  2022-06-26 16:22:00+02:00     naas.ai
#
#                                   AUTHOR_URL SUBDESCRIPTION          TITLE  \
# 0  https://www.linkedin.com/company/70506391   23 hours ago  No comment. 👌
#
#             TEXT  CHARACTER_COUNT TAGS  TAGS_COUNT  ... POLL_ID  \
# 0  No comment. 👌               13  NaN           0  ...     NaN
#
#    POLL_QUESTION POLL_RESULTS  \
# 0            NaN          NaN
#
#                                             POST_URL VIEWS COMMENTS LIKES  \
# 0  https://www.linkedin.com/feed/update/urn:li:ac...   221        0     2
#
#   SHARES ENGAGEMENT_SCORE         DATE_EXTRACT
# 0      0          0.00905  2022-06-27 18:21:50
#
# [1 rows x 31 columns]

# %% [markdown]
# ### Get top posts

# %%
def get_posts(df_init,
              col_date):
    
    # Init variable
    df = df_init.copy()
    df["VIEWS"] = df["VIEWS"].astype(int)
    df["LIKES"] = df["LIKES"].astype(int)
    df["COMMENTS"] = df["COMMENTS"].astype(int)
    df["ENGAGEMENT_SCORE"] = df["ENGAGEMENT_SCORE"].astype(float)
    df[SCENARIO] = pd.to_datetime(df[col_date].str[:-6]).dt.strftime(PERIOD)
    
    # Filter
    df = df[df[SCENARIO] == datetime.now().strftime(PERIOD)].reset_index(drop=True)
    
    # Sort
    df = df.sort_values(by="VIEWS", ascending=False)
    
    # Order
    df = df[["TITLE", "PUBLISHED_DATE", "AUTHOR_NAME", "POST_URL", "VIEWS", "LIKES", "COMMENTS", "SHARES", "ENGAGEMENT_SCORE"]]
    return df.reset_index(drop=True)

df_top = get_posts(df_posts,
                   col_date="PUBLISHED_DATE")
df_top
# Out:
#                                                 TITLE  \
# 0   Want to use AI to label the sentiment of your ...
# 1   Wondering how to read a dataframe from your fi...
# 2                                        Good read !
# 3   Did you know you can send daily billing notifi...
# 4   Critical thinking and problem solving is very ...
# 5   ⚡️ We started a challenge this Monday: aggrega...
# 6   Dashboards do not need to be perfect the first...
# 7   Do you want to download files in your AWS buck...
# 8   Build your company metrics database with naas....
# 9                                       No comment. 👌
# 10  Most of the people working in data think noteb...
# 11  🤙 Nikolaj Groeneweg is putting together someth...
# 12  Rules based approach comes first, and ML can b...
# 13                             Congrats Alok Chilka!
# 14       💎 Brand your charts with your company logo!
# 15                                                 💚🤙
#
#                PUBLISHED_DATE AUTHOR_NAME  \
# 0   2022-06-20 11:33:33+02:00     naas.ai
# 1   2022-06-16 12:59:30+02:00     naas.ai
# 2   2022-06-14 19:41:52+02:00     naas.ai
# 3   2022-06-16 07:36:22+02:00     naas.ai
# 4   2022-06-16 12:08:40+02:00     naas.ai
# 5   2022-06-15 06:44:27+02:00     naas.ai
# 6   2022-06-14 12:54:42+02:00     naas.ai
# 7   2022-06-16 10:50:00+02:00     naas.ai
# 8   2022-06-02 12:53:31+02:00     naas.ai
# 9   2022-06-26 16:22:00+02:00     naas.ai
# 10  2022-06-22 17:52:09+02:00     naas.ai
# 11  2022-06-08 19:39:38+02:00     naas.ai
# 12  2022-06-11 07:09:40+02:00     naas.ai
# 13  2022-06-07 18:44:48+02:00     naas.ai
# 14  2022-06-11 07:19:26+02:00     naas.ai
# 15  2022-06-11 07:14:43+02:00     naas.ai
#
#                                              POST_URL  VIEWS  LIKES  COMMENTS  \
# 0   https://www.linkedin.com/feed/update/urn:li:ac...    743     11         2
# 1   https://www.linkedin.com/feed/update/urn:li:ac...    431      9         0
# 2   https://www.linkedin.com/feed/update/urn:li:ac...    397      3         1
# 3   https://www.linkedin.com/feed/update/urn:li:ac...    367      6         0
# 4   https://www.linkedin.com/feed/update/urn:li:ac...    351      3         2
# 5   https://www.linkedin.com/feed/update/urn:li:ac...    345      9         0
# 6   https://www.linkedin.com/feed/update/urn:li:ac...    318      3         2
# 7   https://www.linkedin.com/feed/update/urn:li:ac...    307      3         0
# 8   https://www.linkedin.com/feed/update/urn:li:ac...    268      3         0
# 9   https://www.linkedin.com/feed/update/urn:li:ac...    221      2         0
# 10  https://www.linkedin.com/feed/update/urn:li:ac...    218      7         0
# 11  https://www.linkedin.com/feed/update/urn:li:ac...    178      4         0
# 12  https://www.linkedin.com/feed/update/urn:li:ac...    161      3         0
# 13  https://www.linkedin.com/feed/update/urn:li:ac...    103      2         0
# 14  https://www.linkedin.com/feed/update/urn:li:ac...     61      0         0
# 15  https://www.linkedin.com/feed/update/urn:li:ac...     58      2         0
#
#     SHARES  ENGAGEMENT_SCORE
# 0        0          0.017497
# 1        0          0.020882
# 2        0          0.010076
# 3        0          0.016349
# 4        0          0.014245
# 5        0          0.026087
# 6        0          0.015723
# 7        0          0.009772
# 8        0          0.011194
# 9        0          0.009050
# 10       0          0.032110
# 11       0          0.022472
# 12       0          0.018634
# 13       0          0.019417
# 14       0          0.000000
# 15       0          0.034483

# %% [markdown]
# ## Output

# %% [markdown]
# ### Update Notion Report

# %%
def update_report_status(report,
                         platform,
                         owner,
                         df=pd.DataFrame(),
                         image_link=None,
                         html_link=None,
                         csv_link=None,
                         page_icon=LOGO,
                         ):
    # Decode database id
    database_id = naas.secret.get(name="NOTION_DATABASE_URL").split("/")[-1].split("?v=")[0]
    
    # Get pages from notion database
    pages = notion.connect(NOTION_TOKEN).database.query(database_id)
    
    # Create or update page
    page_new = True
    for page in pages:
        page_temp = page.df()
        page_id = page_temp.loc[page_temp.Name == "Report name", "Value"].values
        page_id2 = page_temp.loc[page_temp.Name == "Platform", "Value"].values
        page_id3 = page_temp.loc[page_temp.Name == "Owner", "Value"].values
        if page_id == report and page_id2 == platform and page_id3 == owner:
            page_new = False
            break
    try:
        if page_new:
            page = notion.connect(NOTION_TOKEN).Page.new(database_id=database_id).create()
            page.title("Report name", report)
            page.multi_select("Platform", [platform])
            page.select("Owner", owner)
            notion.client.pages.update(page_id=page.id, icon={'type': 'external', 'external': {'url': page_icon}})
            
        # Check if image already exists
        blocks = page.get_blocks()
        if len(blocks) > 0:
            while True:
                for block in blocks:
                    notion.connect(NOTION_TOKEN).blocks.delete(block.id)
                blocks = page.get_blocks()
                if len(blocks) == 0:
                    break
        page.update()
        
        kpis = ["ENGAGEMENT_SCORE", "VIEWS", "COMMENTS", "LIKES"]
        for kpi in kpis:
            heading_3 = f"By {kpi.lower()}"
            if kpi == "ENGAGEMENT_SCORE":
                heading_3 = "By engagement rate"
            page.heading_3(heading_3)
            tmp_df = df.sort_values(by=kpi, ascending=False).reset_index(drop=True)[:3]
            for index, row in tmp_df.iterrows():
                value = row[kpi]
                kpi_d = kpi.lower()
                title = f"{row.TITLE} ({value} {kpi_d})"
                if kpi == "ENGAGEMENT_SCORE":
                    value = "{:,.2%}".format(value)
                    title = f"{row.TITLE} ({value})"
                res = page.numbered_list_item(title)
                res.numbered_list_item.text[0].href = row.POST_URL
                res.numbered_list_item.text[0].text.link = Link(row.POST_URL)
            
        # Create page in Notion
        page.date("Last updated date", datetime.now(pytz.timezone(TIMEZONE)).strftime("%Y-%m-%d %H:%M:%S%z"))
        page.update()
        print(f"✅ Page '{report} - {platform} - {owner}' updated in Notion.")
    except Exception as e:
        raise(e)

update_report_status(KPI_TITLE,
                     PLATFORM,
                     OWNER,
                     df_top)
# Out:
# ✅ Page 'Top posts - LinkedIn - naas.ai' updated in Notion.
