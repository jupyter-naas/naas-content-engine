# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # LinkedIn - Extract content profile world cloud
# <a href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/LinkedIn/Linkedin_Follow_number_of_content_published.ipynb" target="_parent"><img src="https://naasai-public.s3.eu-west-3.amazonaws.com/open_in_naas.svg"/></a>

# %% [markdown]
# **Tags:** #linkedin #html #plotly #csv #image #content #analytics #automation

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# Reference:
# - https://www.datacamp.com/tutorial/wordcloud-python

# %% [markdown]
# ## Input

# %%
# Except allow to run common.ipynb once using Naas Engine
try:
    # %run "../common.ipynb"
except:
    # %run "common.ipynb"

# %% [markdown]
# ### Import libraries

# %%
try:
    from wordcloud import WordCloud
except:
    # !pip install wordcloud --user
    from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %% [markdown]
# ### Setup Variables

# %%
# Inputs
KPI_TITLE = "World cloud"
INPUT_DATABASE = LK_PROFILE_POSTS
OWNER = LK_FULLNAME
OWNER_ID = LK_PROFILE_ID
PLATFORM = LINKEDIN

# Outputs
name_output = f"LINKEDIN_EXTRACT_PROFILE_{KPI_TITLE.lower().replace(' ', '_')}_{OWNER_ID}"
image_output = path.join(LINKEDIN_OUTPUTS, f"{name_output}.png")

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get your post

# %%
df_posts = get_data(INPUT_DATABASE)
print("✅ Posts fetched:", len(df_posts))
df_posts.head(1)
# Out:
# ✅ Posts fetched: 308
#            ACTIVITY_ID                                   PAGINATION_TOKEN  \
# 0  6946906609415544832  dXJuOmxpOmFjdGl2aXR5OjY5NDY5MDY2MDk0MTU1NDQ4Mz...
#
#               PUBLISHED_DATE     AUTHOR_NAME  \
# 0  2022-06-26 19:26:42+02:00  Jérémy Ravenel
#
#                                           AUTHOR_URL SUBDESCRIPTION  \
# 0  https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKH...   12 hours ago
#
#                                                TITLE  \
# 0  If you are interested in data and business, yo...
#
#                                                 TEXT  CHARACTER_COUNT  \
# 0  If you are interested in data and business, yo...             1711
#
#                                                 TAGS  ...  POLL_ID  \
# 0  #66daysofdata #data #business #sales #people #...  ...      NaN
#
#   POLL_QUESTION  POLL_RESULTS  \
# 0           NaN           NaN
#
#                                             POST_URL  VIEWS COMMENTS LIKES  \
# 0  https://www.linkedin.com/feed/update/urn:li:ac...   2482        1    22
#
#   SHARES ENGAGEMENT_SCORE         DATE_EXTRACT
# 0      0           0.0093  2022-06-27 09:42:15
#
# [1 rows x 32 columns]

# %% [markdown]
# ### Create world cloud

# %%
#Creating the text variable
text = " ".join(text for text in df_posts.astype(str).TEXT)

# %%
# Creating word_cloud with text as argument in .generate() method
word_cloud = WordCloud(collocations=False,
                       background_color='white',
                       width=1200,
                       height=600).generate(text)
word_cloud

# %%
# %matplotlib inline

# Display the generated Word Cloud

plt.imshow(word_cloud, interpolation='bilinear')

plt.axis("off")

plt.show()

# %% [markdown]
# ## Output

# %% [markdown]
# ### Save and share your graph in image

# %%
# Save your image in PNG
output_path = save_graph_asset(word_cloud, image_output, image=True)

# Share output with naas
image_link = naas.asset.add(output_path)

#-> Uncomment the line below to remove your asset
# naas.asset.delete(image_output)
# Out:
# 👌 Well done! Your Assets has been sent to production.
# Button(button_style='primary', description='Copy URL', style=ButtonStyle())
# Output()
# PS: to remove the "Assets" feature, just replace .add by .delete

# %% [markdown]
# ### Update Notion Report

# %%
update_report_status(KPI_TITLE,
                     PLATFORM,
                     OWNER,
                     image_link=image_link)
# Out:
# ✅ Page 'World cloud - LinkedIn - Jérémy Ravenel' updated in Notion.
