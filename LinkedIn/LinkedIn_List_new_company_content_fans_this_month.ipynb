# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # LinkedIn - List new company content fans
# <a href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/LinkedIn/Linkedin_Follow_number_of_content_published.ipynb" target="_parent"><img src="https://naasai-public.s3.eu-west-3.amazonaws.com/open_in_naas.svg"/></a>

# %% [markdown]
# **Tags:** #linkedin #html #plotly #csv #image #content #analytics #automation

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# This notebook lists your new fans on your post this month on LinkedIn.

# %% [markdown]
# ## Input

# %%
# Get common path and run it
from os import path

common_path = "../common.ipynb"
if not path.exists(common_path):
    common_path = f"{naas.secret.get('GIT_REPO_NAME')}/common.ipynb"

# %run "$common_path"

# %% [markdown]
# ### Setup Variables

# %%
# Inputs
KPI_TITLE = "New fans"
INPUT_DATABASE = LK_COMPANY_ENGAGEMENTS
OWNER = LK_COMPANY_NAME
OWNER_ID = LK_COMPANY_ID
PLATFORM = LINKEDIN
LOGO = LINKEDIN_LOGO
PERIOD = PERIOD_MTD

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get your engagements

# %%
df_engagements = get_data(INPUT_DATABASE)
print("✅ Engagements fetched:", len(df_engagements))
df_engagements.head(1)
# Out:
# ✅ Engagements fetched: 81
#                                 PROFILE_ID  \
# 0  ACoAABcFJRIBdY-1a-ROxIUo3cNxUMzTmPnUT8M
#
#                                          PROFILE_URL             PUBLIC_ID  \
# 0  https://www.linkedin.com/in/ACoAABcFJRIBdY-1a-...  alexandrestevenspbix
#
#    FIRSTNAME LASTNAME           FULLNAME  \
# 0  Alexandre  STEVENS  Alexandre STEVENS
#
#                                           OCCUPATION  REACTION  \
# 0  Un besoin d'Automatisation & Visualisation de ...  COMMENTS
#
#                        TEXT  \
# 0  Thank you for sharing! 👋
#
#                                                TITLE       PUBLISHED_DATE  \
# 0  🎉Congrats Alexandre STEVENS for creating this ...  2022-07-06 17:14:54
#
#   AUTHOR_NAME                                           POST_URL  \
# 0     naas.ai  https://www.linkedin.com/feed/update/urn:li:ac...
#
#           DATE_EXTRACT
# 0  2022-07-12 14:09:44

# %% [markdown]
# ### Get fans data

# %%
df_fans = get_fans_data(df_engagements)
print("✅ Unique fans fetched:", len(df_fans))
df_fans.head(1)
# Out:
# ✅ Unique fans fetched: 4
#                                 PROFILE_ID  \
# 0  ACoAABcFJRIBdY-1a-ROxIUo3cNxUMzTmPnUT8M
#
#                                          PROFILE_URL             PUBLIC_ID  \
# 0  https://www.linkedin.com/in/ACoAABcFJRIBdY-1a-...  alexandrestevenspbix
#
#    FIRSTNAME LASTNAME           FULLNAME  \
# 0  Alexandre  STEVENS  Alexandre STEVENS
#
#                                           OCCUPATION  REACTION  \
# 0  Un besoin d'Automatisation & Visualisation de ...  COMMENTS
#
#                        TEXT  \
# 0  Thank you for sharing! 👋
#
#                                                TITLE       PUBLISHED_DATE  \
# 0  🎉Congrats Alexandre STEVENS for creating this ...  2022-07-06 17:14:54
#
#   AUTHOR_NAME                                           POST_URL  \
# 0     naas.ai  https://www.linkedin.com/feed/update/urn:li:ac...
#
#           DATE_EXTRACT SCENARIO
# 0  2022-07-12 14:09:44  2022-07

# %% [markdown]
# ## Output

# %% [markdown]
# ### Update Notion Report

# %%
page = list_new_fans(KPI_TITLE,
                     PLATFORM,
                     OWNER,
                     df_engagements,
                     df_fans)
page
# Out:
# ✅ Page 'New fans - LinkedIn - naas.ai' updated in Notion.
