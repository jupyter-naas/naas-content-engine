# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # LinkedIn - List new company content fans
# <a href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/LinkedIn/Linkedin_Follow_number_of_content_published.ipynb" target="_parent"><img src="https://naasai-public.s3.eu-west-3.amazonaws.com/open_in_naas.svg"/></a>

# %% [markdown]
# **Tags:** #linkedin #html #plotly #csv #image #content #analytics #automation

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# This notebook follows the evolution of content shares on LinkedIn.

# %% [markdown]
# ## Input

# %%
# Except allow to run common.ipynb once using Naas Engine
try:
    # %run "../common.ipynb"
except:
    # %run "common.ipynb"

# %% [markdown]
# ### Setup Variables

# %%
KPI_TITLE = "New fans"
INPUT_DATABASE = LK_COMPANY_ENGAGEMENTS
OWNER = LK_COMPANY_NAME
OWNER_ID = LK_COMPANY_ID
PLATFORM = LINKEDIN
LOGO = LINKEDIN_LOGO

# %% [markdown]
# ### Setup Constants

# %%
# Inputs
PERIOD = PERIOD_MTD

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get your engagements

# %%
df_engagements = get_data(INPUT_DATABASE)
print("✅ Engagements fetched:", len(df_engagements))
df_engagements.head(1)
# Out:
# ✅ Engagements fetched: 70
#                                 PROFILE_ID  \
# 0  ACoAABYVsxEBFJ5cAeOCukhSw2dAK8h_pMtwg1E
#
#                                          PROFILE_URL  \
# 0  https://www.linkedin.com/in/ACoAABYVsxEBFJ5cAe...
#
#                    PUBLIC_ID FIRSTNAME LASTNAME          FULLNAME  \
# 0  valentin-piquard-955105a4  Valentin  Piquard  Valentin Piquard
#
#                                           OCCUPATION REACTION         TEXT  \
# 0  Product-Led Growth @Naas.ai | Building an Open...    LIKES  Not defined
#
#            TITLE             PUBLISHED_DATE AUTHOR_NAME  \
# 0  No comment. 👌  2022-06-26 16:22:00+02:00     naas.ai
#
#                                             POST_URL
# 0  https://www.linkedin.com/feed/update/urn:li:ac...

# %% [markdown]
# ### Get fans

# %%
def get_fans(df):
    # Init
    df_fans = df.copy()
    
    # Filter
    df_fans = df_fans.drop_duplicates(["PROFILE_ID", "REACTION"], keep="last").reset_index(drop=True)
    df_fans["SCENARIO"] = pd.to_datetime(df_fans["PUBLISHED_DATE"].str[:-6]).dt.strftime(PERIOD)
    df_fans = df_fans[(df_fans["SCENARIO"] == datetime.now().strftime(PERIOD)) & (df_fans["FULLNAME"] != OWNER)].reset_index(drop=True)
    return df_fans

df_fans = get_fans(df_engagements)
df_fans
# Out:
#                                  PROFILE_ID  \
# 0   ACoAABRK0_8BfD3WlBxZX0cc7IJj7GfYW087PME
# 1   ACoAAABbOD8BF_9zDdGmvl0Tu16BnKqThxQEgik
# 2   ACoAACOIOTUBw_66_cKErK27KlQGu6UbLJqJ7Og
# 3   ACoAABJBNCsBE9LDNIWcaWusUevMLwtXW2ahOgo
# 4   ACoAAABbOD8BF_9zDdGmvl0Tu16BnKqThxQEgik
# 11                                  jeremycare               Jeremy
# 12                            tobias-zwingmann               Tobias
# 13                            tobias-zwingmann               Tobias
# 14                              shaheeb-rahman              Shaheeb
# 15                                maximejublou               Maxime
# 16                        alexandrestevenspbix            Alexandre
# 17                             florent-ravenel              Florent
# 18                               maxime-blasco               Maxime
# 19                                 raoufmazouz                Raouf
# 20                                      nvanda               Nonopa
# 21          sébastien-grech-👨‍💼dislo-4433a7150            Sébastien
# 22                              martindonadieu             🚀 Martin
# 23                                   leekahhow               Kahhow
# 24                                shruthi-jain              Shruthi
# 25                     jérémy-ravenel-8a396910               Jérémy
# 26                     jérémy-ravenel-8a396910               Jérémy
# 27                                eijkelenboom              Gilbert
# 28                          waleed-elhardallou               Waleed
# 29                        gaspard-nzasabimfura              Gaspard
# 30                                     asifsyd                 𝙰𝚜𝚒𝚏
# 31                       oj-onyeagwu-4ba477164                   OJ
# 32                                      smasis                 Serg
# 33                   valentin-piquard-955105a4             Valentin
# 34                                  peacebello                Peace
# 35                                     calok64                 Alok
# 36                                   imasdekar                Ishan
# 37                      adnan-alsnwi-17ba2a134                Adnan
# 38                                  richarddze              Richard
# 39                        sriniketh-jayasendil            Sriniketh
#
#               LASTNAME                          FULLNAME  \
# 0               Medhat                     Hossam Medhat
# 1            Groeneweg                 Nikolaj Groeneweg
# 2         BHUPATHIRAJU  VINAY CHANDRA VARMA BHUPATHIRAJU
# 3                Fol 🌱                     🌏 Yoann Fol 🌱
# 4            Groeneweg                 Nikolaj Groeneweg
# 5               Emiral              Oktay Cansın  Emiral
# 6                thida                         Myo thida
# 7           Srivastava                  Pooja Srivastava
# 8               Emiral              Oktay Cansın  Emiral
# 9               Choppe                  Jean-Gaël Choppe
# 10               Botha                      Debbie Botha
# 11                Care                       Jeremy Care
# 12           Zwingmann                  Tobias Zwingmann
# 13           Zwingmann                  Tobias Zwingmann
# 14              Rahman                    Shaheeb Rahman
# 15              Jublou                     Maxime Jublou
# 16             STEVENS                 Alexandre STEVENS
# 17             Ravenel                   Florent Ravenel
# 18              Blasco                     Maxime Blasco
# 19              Mazouz                      Raouf Mazouz
# 20       Vanda  ⚖ 🇿🇦 🌍              Nonopa Vanda  ⚖ 🇿🇦 🌍
# 21    GRECH - 👨‍💼Dislo        Sébastien GRECH - 👨‍💼Dislo
# 22            DONADIEU                 🚀 Martin DONADIEU
# 23                  L.                         Kahhow L.
# 24                Jain                      Shruthi Jain
# 25             Ravenel                    Jérémy Ravenel
# 26             Ravenel                    Jérémy Ravenel
# 27        Eijkelenboom              Gilbert Eijkelenboom
# 28         Elhardallou                Waleed Elhardallou
# 29  NZASABIMANA IMFURA        Gaspard NZASABIMANA IMFURA
# 30                𝚂𝚢𝚎𝚍                         𝙰𝚜𝚒𝚏 𝚂𝚢𝚎𝚍
# 31            Onyeagwu                       OJ Onyeagwu
# 32               Masís                        Serg Masís
# 33             Piquard                  Valentin Piquard
# 34               Bello                       Peace Bello
# 35              Chilka                       Alok Chilka
# 36            Masdekar                    Ishan Masdekar
# 37              Alsnwi                      Adnan Alsnwi
# 38                 Dze                       Richard Dze
# 39          Jayasendil              Sriniketh Jayasendil
#
#                                            OCCUPATION  REACTION  \
# 0   Associate Product Manager | Business Analyst |...     LIKES
# 1                        Data & AI · La French Tech 🚀  COMMENTS
# 2   Economic Times Brightest Engineer of India (20...     LIKES
# 3   People, Planet, Profit ❤️ | Data Scientist | T...     LIKES
# 4                        Data & AI · La French Tech 🚀     LIKES
# 5                                                 CEO     LIKES
# 6   Social Entrepreneur| Data Scientist | ASEAN Sc...     LIKES
# 7   Applied AI & ML | Industrial IOT | Cloud & Mic...     LIKES
# 8                                                 CEO  COMMENTS
# 9           CTO & Lead DevOps Engineer at SmartSoccer     LIKES
# 10       Women in AI Global Chief Partnership Officer     LIKES
# 11  Lead Software Engineer at TrackIt | Freelance ...     LIKES
# 12  Senior Data Scientist • Data Science Mentor • ...  COMMENTS
# 13  Senior Data Scientist • Data Science Mentor • ...     LIKES
# 14  Data Engineering Architect with 12 yrs experie...     LIKES
# 15  CTO @naas.ai | Cloud, DevOps and Software deve...     LIKES
# 16  CEO @Dislo.ai - J'aide les services finances à...     LIKES
# 17  COO @Naas.ai | Automation and data templates i...     LIKES
# 18  ✍️ J'écris les contenus de fintech et cabinets...     LIKES
# 19  Data Scientist | ERP Expert | ML & AI Enthusia...     LIKES
# 20  I help lawyers and businesses get discovered |...     LIKES
# 21  Co-Founder & COO @Dislo | ✴️ Transformez vos d...     LIKES
# 22  I help you launch your solo startup without ra...     LIKES
# 23                           Educator | Edtech | Bboy     LIKES
# 24                             |Data Analyst at Xeno|     LIKES
# 25  ⚡️ Building @naas.ai - open source data platfo...     LIKES
# 26  ⚡️ Building @naas.ai - open source data platfo...  COMMENTS
# 27  Communication skills training for Data & Analy...  COMMENTS
# 28    Digital Marketing Specialist at ShareColours.Se     LIKES
# 29  Data Analyst, Scientist & Engineer | Telecom &...     LIKES
# 30  I swear I wasn't wearing a life vest when I ju...     LIKES
# 31  Data Analyst at McMaster Manufacturing Researc...     LIKES
# 32    Data Scientist | Interpretable Machine Learning     LIKES
# 33  Product-Led Growth @Naas.ai | Building an Open...     LIKES
# 34  Chemical Engineering Finalist|| Process Optimi...     LIKES
# 35  CRM and Automation Specialist @ Wireless DNA |...     LIKES
# 36  Automation Solution and Python Developer in Ri...     LIKES
# 37                     Master in Software Engineering     LIKES
# 38  Data Scientist | Google Explore ML with Crowds...     LIKES
# 39  DS & ML Enthusiast | Learning Web Dev | Open S...     LIKES
#
#                                                  TEXT  \
# 0                                         Not defined
# 1                              Thanks for the share 🤗
# 2                                         Not defined
# 3                                         Not defined
# 4                                         Not defined
# 5                                         Not defined
# 6                                         Not defined
# 7                                         Not defined
# 8   Isn't this power app sentiment analysis, very ...
# 9                                         Not defined
# 10                                        Not defined
# 11                                        Not defined
# 12                          Thanks for the shout out!
# 13                                        Not defined
# 14                                        Not defined
# 15                                        Not defined
# 16                                        Not defined
# 17                                        Not defined
# 18                                        Not defined
# 19                                        Not defined
# 20                                        Not defined
# 21                                        Not defined
# 22                                        Not defined
# 23                                        Not defined
# 24                                        Not defined
# 25                                        Not defined
# 26                                                  👌
# 27                    Thank you for the share naas.ai
# 28                                        Not defined
# 29                                        Not defined
# 30                                        Not defined
# 31                                        Not defined
# 32                                        Not defined
# 33                                        Not defined
# 34                                        Not defined
# 35                                        Not defined
# 36                                        Not defined
# 37                                        Not defined
# 38                                        Not defined
# 39                                        Not defined
#
#                                                 TITLE  \
# 0                                       No comment. 👌
# 1   Want to use AI to label the sentiment of your ...
# 2   Want to use AI to label the sentiment of your ...
# 3   Want to use AI to label the sentiment of your ...
# 4   Want to use AI to label the sentiment of your ...
# 5   Want to use AI to label the sentiment of your ...
# 6   Want to use AI to label the sentiment of your ...
# 7   Want to use AI to label the sentiment of your ...
# 8   Want to use AI to label the sentiment of your ...
# 9   Wondering how to read a dataframe from your fi...
# 10  Wondering how to read a dataframe from your fi...
# 11  Wondering how to read a dataframe from your fi...
# 12  Critical thinking and problem solving is very ...
# 13  Critical thinking and problem solving is very ...
# 14  Do you want to download files in your AWS buck...
# 15  Did you know you can send daily billing notifi...
# 16  Did you know you can send daily billing notifi...
# 17  Did you know you can send daily billing notifi...
# 18  ⚡️ We started a challenge this Monday: aggrega...
# 19  ⚡️ We started a challenge this Monday: aggrega...
# 20  ⚡️ We started a challenge this Monday: aggrega...
# 21  ⚡️ We started a challenge this Monday: aggrega...
# 22  ⚡️ We started a challenge this Monday: aggrega...
# 23  ⚡️ We started a challenge this Monday: aggrega...
# 24  ⚡️ We started a challenge this Monday: aggrega...
# 25                                       Good read !
# 26                                       Good read !
# 27  Dashboards do not need to be perfect the first...
# 28  Dashboards do not need to be perfect the first...
# 29  Dashboards do not need to be perfect the first...
# 30                                                 💚🤙
# 31  Rules based approach comes first, and ML can b...
# 32  Rules based approach comes first, and ML can b...
# 33  🤙 Nikolaj Groeneweg is putting together someth...
# 34  🤙 Nikolaj Groeneweg is putting together someth...
# 35                             Congrats Alok Chilka!
# 36                             Congrats Alok Chilka!
# 37  Build your company metrics database with naas....
# 38  Build your company metrics database with naas....
# 39  Build your company metrics database with naas....
#
#                PUBLISHED_DATE AUTHOR_NAME  \
# 0   2022-06-26 16:22:00+02:00     naas.ai
# 1   2022-06-20 11:33:33+02:00     naas.ai
# 2   2022-06-20 11:33:33+02:00     naas.ai
# 3   2022-06-20 11:33:33+02:00     naas.ai
# 4   2022-06-20 11:33:33+02:00     naas.ai
# 5   2022-06-20 11:33:33+02:00     naas.ai
# 6   2022-06-20 11:33:33+02:00     naas.ai
# 7   2022-06-20 11:33:33+02:00     naas.ai
# 8   2022-06-20 11:33:33+02:00     naas.ai
# 9   2022-06-16 12:59:30+02:00     naas.ai
# 10  2022-06-16 12:59:30+02:00     naas.ai
# 11  2022-06-16 12:59:30+02:00     naas.ai
# 12  2022-06-16 12:08:40+02:00     naas.ai
# 13  2022-06-16 12:08:40+02:00     naas.ai
# 14  2022-06-16 10:50:00+02:00     naas.ai
# 15  2022-06-16 07:36:22+02:00     naas.ai
# 16  2022-06-16 07:36:22+02:00     naas.ai
# 17  2022-06-16 07:36:22+02:00     naas.ai
# 18  2022-06-15 06:44:27+02:00     naas.ai
# 19  2022-06-15 06:44:27+02:00     naas.ai
# 20  2022-06-15 06:44:27+02:00     naas.ai
# 21  2022-06-15 06:44:27+02:00     naas.ai
# 22  2022-06-15 06:44:27+02:00     naas.ai
# 23  2022-06-15 06:44:27+02:00     naas.ai
# 34  https://www.linkedin.com/feed/update/urn:li:ac...  2022-06
# 35  https://www.linkedin.com/feed/update/urn:li:ac...  2022-06
# 36  https://www.linkedin.com/feed/update/urn:li:ac...  2022-06
# 37  https://www.linkedin.com/feed/update/urn:li:ac...  2022-06
# 38  https://www.linkedin.com/feed/update/urn:li:ac...  2022-06
# 39  https://www.linkedin.com/feed/update/urn:li:ac...  2022-06

# %% [markdown]
# ## Output

# %% [markdown]
# ### Update Notion Report

# %%
def update_report_status(report,
                         platform,
                         owner,
                         df_engagements,
                         df=pd.DataFrame(),
                         image_link=None,
                         html_link=None,
                         csv_link=None,
                         page_icon=LOGO,
                         ):
    # Decode database id
    database_id = naas.secret.get(name="NOTION_DATABASE_URL").split("/")[-1].split("?v=")[0]
    
    # Get pages from notion database
    pages = notion.connect(NOTION_TOKEN).database.query(database_id)
    
    # Create or update page
    page_new = True
    for page in pages:
        page_temp = page.df()
        page_id = page_temp.loc[page_temp.Name == "Report name", "Value"].values
        page_id2 = page_temp.loc[page_temp.Name == "Platform", "Value"].values
        page_id3 = page_temp.loc[page_temp.Name == "Owner", "Value"].values
        if page_id == report and page_id2 == platform and page_id3 == owner:
            page_new = False
            break
    try:
#         notion.connect(NOTION_TOKEN).blocks.delete(page.id)
        if page_new:
            page = notion.connect(NOTION_TOKEN).Page.new(database_id=database_id).create()
            page.title("Report name", report)
            page.multi_select("Platform", [platform])
            page.select("Owner", owner)
            notion.client.pages.update(page_id=page.id, icon={'type': 'external', 'external': {'url': page_icon}})
            
        # Check if image already exists
        blocks = page.get_blocks()
        if len(blocks) > 0:
            while True:
                for block in blocks:
                    notion.connect(NOTION_TOKEN).blocks.delete(block.id)
                blocks = page.get_blocks()
                if len(blocks) == 0:
                    break
        page.update()
        
        # Add new fans by posts
        df_posts = df_engagements[["TITLE", "POST_URL", "PUBLISHED_DATE"]].drop_duplicates().reset_index(drop=True)[:10]
        for index, row in df_posts.iterrows():
            # Add posts
            res = page.heading_3(row.TITLE)
            res.heading_3.text[0].href = row.POST_URL
            res.heading_3.text[0].text.link = Link(row.POST_URL)
            
            # Add new
            tmp_df = df[df.POST_URL == row.POST_URL].reset_index(drop=True)
            def add_reactions(df, reaction):
                df = df[df.REACTION == reaction]
                if reaction == "LIKES":
                    page.paragraph(f"New profile who liked ({len(df)}):")
                elif reaction == "COMMENTS":
                    page.paragraph(f"New profile who commented ({len(df)}):")
                for index, row in df.iterrows():
                    text = f"{row.FULLNAME} - {row.OCCUPATION}"
                    res = page.bulleted_list_item(text)
                    res.bulleted_list_item.text[0].href = row.PROFILE_URL
                    res.bulleted_list_item.text[0].text.link = Link(row.PROFILE_URL)
                page.paragraph("")
            add_reactions(tmp_df, "COMMENTS")
            add_reactions(tmp_df, "LIKES")


        # Create page in Notion
        page.date("Last updated date", datetime.now(pytz.timezone(TIMEZONE)).strftime("%Y-%m-%d %H:%M:%S%z"))
        page.update()
        print(f"✅ Page '{report} - {platform} - {owner}' updated in Notion.")
    except Exception as e:
        raise(e)

update_report_status(KPI_TITLE,
                     PLATFORM,
                     OWNER,
                     df_engagements,
                     df_fans)
# Out:
# ✅ Page 'New fans - LinkedIn - naas.ai' updated in Notion.
