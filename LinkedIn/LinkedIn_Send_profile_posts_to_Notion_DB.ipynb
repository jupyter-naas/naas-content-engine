# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # LinkedIn - Send profile posts to Notion DB
# <a href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/LinkedIn/LinkedIn_Update_metrics_from_posts_in_Notion_content_calendar.ipynb" target="_parent"><img src="https://naasai-public.s3.eu-west-3.amazonaws.com/open_in_naas.svg"/></a>

# %% [markdown]
# **Tags:** #linkedin #profile #post #feed #naas_drivers #notion #automation #analytics #naas #scheduler #content #plotly #html #csv #image

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# With this notebook, you can update your content calendar in Notion with all metrics from any profile posts in LinkedIn:
# - **Publication date:** When the post has been published.
# - **Name:** First sentence of post.
# - **Author:** Name of post author.
# - **Content type:** Content type of post (Image, Text, Video, Article, Polls).
# - **Platform:** "LinkedIn" by default.
# - **Status:** "Published ✨" by default.
# - **Engagment score:** Ratio between views and likes/comments (It will be at 0 if you are not the author of the post)
# - **Views:** Amount of people who saw the content (Only available on your profile)
# - **Likes:** Amount of people who pushed the like (or other reaction) button
# - **Comments:** Amount of people who wrote something in the comment section.
# - **Shares:** Amount of people who shared the content.
# - **Profile mention:** People mentioned in post.
# - **Company mention:** Companies mentioned in post.
# - **Nb Tags:** Number of hashtags.
# - **Tags:** List of the hashtags.
# - **Nb emojis:** Number of emojis.
# - **Emojis:** List of emojis.
# - **Nb links:** Number of links.
# - **Links:** Links used in posts.
# - **Nb characters:** Number of characters in post.
# - **Content URL:** URL of the content
# - **Last refresh:** Date of last refresh

# %% [markdown]
# ## Input

# %% [markdown]
# ### Get common variables, functions

# %%
# Except allow to run common.ipynb once using Naas Engine
try:
    # %run "../common.ipynb"
except:
    # %run "common.ipynb"

# %% [markdown]
# ### Setup Variables

# %%
INPUT_DATABASE = LK_PROFILE_POSTS
OWNER = LK_FULLNAME

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get Notion DB

# %%
df_notion = get_notion_df(NOTION_CONTENT_DB)
df_notion
# Out:
# ✅ Notion content DB: 447
#      Platform                                        Content URL  \
# 0    LinkedIn  https://www.linkedin.com/feed/update/urn:li:ac...
# 1    LinkedIn  https://www.linkedin.com/feed/update/urn:li:ac...
# 2    LinkedIn  https://www.linkedin.com/feed/update/urn:li:ac...
# 3    LinkedIn  https://www.linkedin.com/feed/update/urn:li:ac...
# 4    LinkedIn  https://www.linkedin.com/feed/update/urn:li:ac...
# ..        ...                                                ...
# 442  LinkedIn  https://www.linkedin.com/feed/update/urn:li:ac...
# 443  LinkedIn  https://www.linkedin.com/feed/update/urn:li:ac...
# 444  LinkedIn  https://www.linkedin.com/feed/update/urn:li:ac...
# 445  LinkedIn  https://www.linkedin.com/feed/update/urn:li:ac...
# 446  LinkedIn  https://www.linkedin.com/feed/update/urn:li:ac...
#
#                   Publication Date                     Links Engagment score  \
# 0    2022-06-30T15:49:00.000+02:00                      None          0.0117
# 1    2022-06-28T21:45:00.000+02:00                      None          0.0165
# 2    2022-06-28T16:48:00.000+02:00                      None          0.0213
# 3    2022-06-27T19:27:00.000+02:00                      None          0.0111
# 4    2022-06-26T19:26:00.000+02:00  https://lnkd.in/ed3_MKUz           0.008
# ..                             ...                       ...             ...
# 442  2019-06-04T11:26:00.000+02:00   https://lnkd.in/eZzdHz6          0.6087
# 443  2019-04-23T11:53:00.000+02:00   https://lnkd.in/ddDx28s          1.5238
# 444  2019-03-19T07:00:00.000+01:00                      None          4.8182
# 445  2018-07-24T18:16:00.000+02:00                      None               0
# 446  2016-09-30T12:43:00.000+02:00                      None               0
#
#     Content type Likes Views       Status Nb tags  ... Comments  \
# 0          Image    32  3003  Published ✨      21  ...        3
# 1          Image    56  3951  Published ✨      10  ...        9
# 2          Image    31  2347  Published ✨      11  ...       19
# 3          Image    41  4228  Published ✨      11  ...        6
# 4        Article    28  3614  Published ✨      13  ...        1
# ..           ...   ...   ...          ...     ...  ...      ...
# 442         Text    14    23  Published ✨       6  ...        0
# 443         Text    83    63  Published ✨       4  ...       13
# 444        Image    51    11  Published ✨      11  ...        2
# 445      Article     8     0  Published ✨       3  ...        0
# 446         Text     1     0  Published ✨       0  ...        0
#
#                            Emojis           Author Shares  \
# 0       🪄, 🤔, 👉, 🐍, ✅, ✅, ✅, ✅, 😇  Florent Ravenel      0
# 1                                   Jérémy Ravenel      0
# 2    ✏️, 🧑‍🤝‍🧑, 📈, 🌟, ✋, ☀️, 🙏, 😎  Florent Ravenel      0
# 3                      🐍, 🎨, 😇, 👇   Jérémy Ravenel      0
# 4                                   Jérémy Ravenel      0
# ..                            ...              ...    ...
# 442                                 Jérémy Ravenel      0
# 443                    📹, 🚀, 🙏, ❓   Jérémy Ravenel      0
# 444                          🚀, 👍   Jérémy Ravenel      0
# 445                                 Jérémy Ravenel      0
# 446                            []  Florent Ravenel      0
#
#                                                   Tags Nb links Nb emojis  \
# 0    #naaslife #opensource #buildinpublic #datascie...        0         9
# 1    #66daysofdata #language #google #python #trend...        0         1
# 2    #data #socialmedia #linkedin #project #buildin...        0         8
# 3    #66daysofdata #python #future #content #creati...        0         4
# 4    #66daysofdata #data #business #sales #people #...        1         1
# ..                                                 ...      ...       ...
# 442  #DAFDAY #automation #ai #finance #assistant #b...        1         0
# 443      #agile #ia #datastorytelling #futureoffinance        1         4
# 444  #datastorytelling #rpa #ai #reporting #automat...        0         2
# 445     #moneyisfuel #cashstory #financetransformation        0         1
# 446                                                 []        0         0
#
#     Profile mention Nb characters  \
# 0                            1040
# 1                             766
# 2                            1351
# 3                             641
# 4                            1711
# ..              ...           ...
# 442                           324
# 443                           404
# 444                           310
# 445                           250
# 446                             0
#
#                                                   Name
# 0    🪄 Use Jupyter notebooks to building up data pi...
# 1    Do you want to follow the trend of keywords on...
# 2    ✏️ Are you creating content on your LinkedIn p...
# 3    Did you know you can create GIFs with Python? ...
# 4    If you are interested in data and business, yo...
# ..                                                 ...
# 442  CashStory | Financial Data Assistant sera prés...
# 443  CashStory | Financial Data Assistant en 3 minu...
# 444  CashStory | Financial Data Assistant is at Uni...
# 445  Money is fuel, it’s helping you go somewhere! ...
# 446
#
# [447 rows x 21 columns]

# %% [markdown]
# ### Get your posts

# %%
df_posts = get_data(INPUT_DATABASE)
print("✅ Posts fetched:", len(df_posts))
df_posts.head(1)
# Out:
# ✅ Posts fetched: 23
#            ACTIVITY_ID                                   PAGINATION_TOKEN  \
# 0  6948301377668317184  dXJuOmxpOmFjdGl2aXR5OjY5NDgzMDEzNzc2NjgzMTcxOD...
#
#               PUBLISHED_DATE      AUTHOR_NAME  \
# 0  2022-06-30 15:49:01+02:00  Florent Ravenel
#
#                                           AUTHOR_URL SUBDESCRIPTION  \
# 0  https://www.linkedin.com/in/ACoAABCNSioBW3YZHc...     2 days ago
#
#                                                TITLE  \
# 0  🪄 Use Jupyter notebooks to building up data pi...
#
#                                                 TEXT  CHARACTER_COUNT  \
# 0  🪄 Use Jupyter notebooks to building up data pi...             1040
#
#                                                 TAGS  ...  POLL_ID  \
# 0  #naaslife #opensource #buildinpublic #datascie...  ...      NaN
#
#   POLL_QUESTION  POLL_RESULTS  \
# 0           NaN           NaN
#
#                                             POST_URL  VIEWS COMMENTS LIKES  \
# 0  https://www.linkedin.com/feed/update/urn:li:ac...   3495        4    35
#
#   SHARES ENGAGEMENT_SCORE         DATE_EXTRACT
# 0      0           0.0112  2022-07-03 13:44:16
#
# [1 rows x 32 columns]

# %% [markdown]
# ### Update last posts

# %%
def get_last_posts(df_notion, df_posts, owner):
    # Update all posts
    df_update = df_posts.copy()
    
    # Filter to get owner posts in Notion DB
    if len(df_notion) > 0:
        df_owner = df_notion[df_notion.Author == owner]
        if len(df_owner) > 0:
            df_update = df_posts[:7]        
    return df_update

df_update = get_last_posts(df_notion, df_posts, OWNER)
df_update
# Out:
#            ACTIVITY_ID                                   PAGINATION_TOKEN  \
# 0  6948301377668317184  dXJuOmxpOmFjdGl2aXR5OjY5NDgzMDEzNzc2NjgzMTcxOD...
# 1  6947591561702473728  dXJuOmxpOmFjdGl2aXR5OjY5NDc1OTE1NjE3MDI0NzM3Mj...
# 2  6942099568310280193  dXJuOmxpOmFjdGl2aXR5OjY5NDIwOTk1NjgzMTAyODAxOT...
# 3  6941032786308833280  dXJuOmxpOmFjdGl2aXR5OjY5NDEwMzI3ODYzMDg4MzMyOD...
# 4  6940704109431820288  dXJuOmxpOmFjdGl2aXR5OjY5NDA3MDQxMDk0MzE4MjAyOD...
# 5  6938105183885250560  dXJuOmxpOmFjdGl2aXR5OjY5MzgxMDUxODM4ODUyNTA1Nj...
# 6  6936740037581520896  dXJuOmxpOmFjdGl2aXR5OjY5MzY3NDAwMzc1ODE1MjA4OT...
# 7  6935277311495688192  dXJuOmxpOmFjdGl2aXR5OjY5MzUyNzczMTE0OTU2ODgxOT...
# 8  6933071554826166272  dXJuOmxpOmFjdGl2aXR5OjY5MzMwNzE1NTQ4MjYxNjYyNz...
# 9  6932377970628026368  dXJuOmxpOmFjdGl2aXR5OjY5MzIzNzc5NzA2MjgwMjYzNj...
#
#               PUBLISHED_DATE      AUTHOR_NAME  \
# 0  2022-06-30 15:49:01+02:00  Florent Ravenel
# 1  2022-06-28 16:48:28+02:00  Florent Ravenel
# 2  2022-06-13 13:05:15+02:00  Florent Ravenel
# 3  2022-06-10 14:26:14+02:00  Florent Ravenel
# 4  2022-06-09 16:40:11+02:00  Florent Ravenel
# 5  2022-06-02 12:32:59+02:00  Florent Ravenel
# 6  2022-05-29 18:08:23+02:00  Florent Ravenel
# 7  2022-05-25 17:16:02+02:00  Florent Ravenel
# 8  2022-05-19 15:11:08+02:00  Florent Ravenel
# 9  2022-05-17 17:15:05+02:00  Florent Ravenel
#
#                                           AUTHOR_URL SUBDESCRIPTION  \
# 0  https://www.linkedin.com/in/ACoAABCNSioBW3YZHc...     2 days ago
# 1  https://www.linkedin.com/in/ACoAABCNSioBW3YZHc...     4 days ago
# 2  https://www.linkedin.com/in/ACoAABCNSioBW3YZHc...    2 weeks ago
# 3  https://www.linkedin.com/in/ACoAABCNSioBW3YZHc...    3 weeks ago
# 4  https://www.linkedin.com/in/ACoAABCNSioBW3YZHc...    3 weeks ago
# 5  https://www.linkedin.com/in/ACoAABCNSioBW3YZHc...    1 month ago
# 6  https://www.linkedin.com/in/ACoAABCNSioBW3YZHc...    1 month ago
# 7  https://www.linkedin.com/in/ACoAABCNSioBW3YZHc...    1 month ago
# 8  https://www.linkedin.com/in/ACoAABCNSioBW3YZHc...    1 month ago
# 9  https://www.linkedin.com/in/ACoAABCNSioBW3YZHc...    1 month ago
#
#                                                TITLE  \
# 0  🪄 Use Jupyter notebooks to building up data pi...
# 1  ✏️ Are you creating content on your LinkedIn p...
# 2            How old do you look... to a computer? 👀
# 3  ⚙️ Make your chart more business ready with a ...
# 4  Get in touch with more contacts through your L...
# 5  You’re becoming aware that I love to give tips...
# 6  ✏️ If you want to pull all your LinkedIn posts...
# 7  What are you waiting for to start data science...
# 8  Always happy to see data-scientist performing ...
# 9  Are you sure your network growth strategy is w...
#
#                                                 TEXT  CHARACTER_COUNT  \
# 0  🪄 Use Jupyter notebooks to building up data pi...             1040
# 1  ✏️ Are you creating content on your LinkedIn p...             1351
# 2  How old do you look... to a computer? 👀\n\n\nA...              694
# 3  ⚙️ Make your chart more business ready with a ...             1037
# 4  Get in touch with more contacts through your L...              848
# 5  You’re becoming aware that I love to give tips...              557
# 6  ✏️ If you want to pull all your LinkedIn posts...              309
# 7  What are you waiting for to start data science...             1281
# 8  Always happy to see data-scientist performing ...              349
# 9  Are you sure your network growth strategy is w...              865
#
#                                                 TAGS  ...       POLL_ID  \
# 0  #naaslife #opensource #buildinpublic #datascie...  ...           NaN
# 1  #data #socialmedia #linkedin #project #buildin...  ...           NaN
# 2  #ai #naas #datascience #dataanalytics #awesome...  ...           NaN
# 3  #naaslife #opensource #buildinpublic #datascie...  ...           NaN
# 4  #naaslife #opensource #buildinpublic #datascie...  ...           NaN
# 5  #content #contentmarketing #contentcreators #l...  ...  6.938105e+18
# 6  #opensourcecommunity #naas #buildinpublic #dat...  ...           NaN
# 7  #data #datascience #opensource #community #tem...  ...           NaN
# 8  #naas #datascience #dataanalytics #linkedinpos...  ...           NaN
# 9  #naaslife #opensource #buildinpublic #datascie...  ...           NaN
#
#                                        POLL_QUESTION  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  What tool do you use the most for your content...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                         POLL_RESULTS  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  {'LinkedIn': 20, 'Twitter': 4, 'YouTube': 2, '...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                             POST_URL  VIEWS COMMENTS LIKES  \
# 0  https://www.linkedin.com/feed/update/urn:li:ac...   3495        4    35
# 1  https://www.linkedin.com/feed/update/urn:li:ac...   2443       19    32
# 2  https://www.linkedin.com/feed/update/urn:li:ac...    679        2     6
# 3  https://www.linkedin.com/feed/update/urn:li:ac...   1483        2    10
# 4  https://www.linkedin.com/feed/update/urn:li:ac...   2585        5    23
# 5  https://www.linkedin.com/feed/update/urn:li:ac...   1716        5     5
# 6  https://www.linkedin.com/feed/update/urn:li:ac...   2697        5    39
# 7  https://www.linkedin.com/feed/update/urn:li:ac...   7192        6    61
# 8  https://www.linkedin.com/feed/update/urn:li:ac...   1093        3    12
# 9  https://www.linkedin.com/feed/update/urn:li:ac...   2220        7    26
#
#   SHARES ENGAGEMENT_SCORE         DATE_EXTRACT
# 0      0           0.0112  2022-07-03 13:44:16
# 1      0           0.0209  2022-07-03 13:44:17
# 2      0           0.0118  2022-07-03 13:44:18
# 3      0           0.0081  2022-07-03 13:44:18
# 4      0           0.0108  2022-07-03 13:44:19
# 5      0           0.0058  2022-07-03 13:44:20
# 6      0           0.0163  2022-07-03 13:44:21
# 7      0           0.0093  2022-07-03 13:44:21
# 8      0           0.0137  2022-07-03 13:44:22
# 9      0           0.0149  2022-07-03 13:44:22
#
# [10 rows x 32 columns]

# %% [markdown]
# ## Output

# %% [markdown]
# ### Update posts in Notion

# %%
update_content_notion(df_update, NOTION_CONTENT_DB)
# Out:
# https://www.linkedin.com/feed/update/urn:li:activity:6948301377668317184
# 📈 Post stats updated in notion for page '🪄 Use Jupyter notebooks to building up data pipelines with ‘%run’ magic command in Python in no time.'.
#
# https://www.linkedin.com/feed/update/urn:li:activity:6947591561702473728
# 📈 Post stats updated in notion for page '✏️ Are you creating content on your LinkedIn profile and company page? What if you could analyze your engagements and more, using Notion?'.
#
# https://www.linkedin.com/feed/update/urn:li:activity:6942099568310280193
# 📈 Post stats updated in notion for page 'How old do you look... to a computer? 👀'.
#
# https://www.linkedin.com/feed/update/urn:li:activity:6941032786308833280
# 📈 Post stats updated in notion for page '⚙️ Make your chart more business ready with a company logo with Plotly! '.
#
# https://www.linkedin.com/feed/update/urn:li:activity:6940704109431820288
# 📈 Post stats updated in notion for page 'Get in touch with more contacts through your LinkedIn post in less than 5 min!'.
#
# https://www.linkedin.com/feed/update/urn:li:activity:6938105183885250560
# 📈 Post stats updated in notion for page 'You’re becoming aware that I love to give tips and insights. Today, I need yours!'.
#
# https://www.linkedin.com/feed/update/urn:li:activity:6936740037581520896
# 📈 Post stats updated in notion for page '✏️ If you want to pull all your LinkedIn posts metrics into a Notion database to analyze engagement and more, check out the tutorial video (in french 🇫🇷) made by Kevin Rosamont Prombo!'.
#
# https://www.linkedin.com/feed/update/urn:li:activity:6935277311495688192
# 📈 Post stats updated in notion for page 'What are you waiting for to start data science? Are you scared?'.
#
# https://www.linkedin.com/feed/update/urn:li:activity:6933071554826166272
# 📈 Post stats updated in notion for page 'Always happy to see data-scientist performing analysis on its LinkedIn posts stats... Especially when it's based on our templates! 😇'.
#
# https://www.linkedin.com/feed/update/urn:li:activity:6932377970628026368
# 📈 Post stats updated in notion for page 'Are you sure your network growth strategy is working on LinkedIn? This template is a must to be on the safe side.'.
