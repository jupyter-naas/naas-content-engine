# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # LinkedIn - List new profile content fans
# <a href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/LinkedIn/Linkedin_Follow_number_of_content_published.ipynb" target="_parent"><img src="https://naasai-public.s3.eu-west-3.amazonaws.com/open_in_naas.svg"/></a>

# %% [markdown]
# **Tags:** #linkedin #html #plotly #csv #image #content #analytics #automation

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# This notebook lists your new fans on your post this month on LinkedIn.

# %% [markdown]
# ## Input

# %%
# Get common path and run it
from os import path

common_path = "../common.ipynb"
if not path.exists(common_path):
    common_path = f"{naas.secret.get('GIT_REPO_NAME')}/common.ipynb"

# %run "$common_path"

# %% [markdown]
# ### Setup Variables

# %%
# Inputs
KPI_TITLE = "New fans"
INPUT_DATABASE = LK_PROFILE_ENGAGEMENTS
OWNER = LK_FULLNAME
OWNER_ID = LK_PROFILE_ID
PLATFORM = LINKEDIN
LOGO = LINKEDIN_LOGO
PERIOD = PERIOD_MTD

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get your engagements

# %%
df_engagements = get_data(INPUT_DATABASE)
print("✅ Engagements fetched:", len(df_engagements))
df_engagements.head(1)
# Out:
# ✅ Engagements fetched: 350
#                                 PROFILE_ID  \
# 0  ACoAABj9-uYBnQaJqrt0G7KWMwfLT2m_eyUcEf0
#
#                                          PROFILE_URL     PUBLIC_ID FIRSTNAME  \
# 0  https://www.linkedin.com/in/ACoAABj9-uYBnQaJqr...  calebmkeller     Caleb
#
#   LASTNAME      FULLNAME                                         OCCUPATION  \
# 0   Keller  Caleb Keller  The Notebooks Guy | Data Driven Value through ...
#
#   REACTION         TEXT                                              TITLE  \
# 0    LIKES  Not defined  📧 If you are using Sendinblue for your email c...
#
#              PUBLISHED_DATE      AUTHOR_NAME  \
# 0  2022-07-11 15:29:09+0200  Florent Ravenel
#
#                                             POST_URL         DATE_EXTRACT
# 0  https://www.linkedin.com/feed/update/urn:li:ac...  2022-07-12 14:06:33

# %% [markdown]
# ### Get fans data

# %%
df_fans = get_fans_data(df_engagements)
print("✅ Unique fans fetched:", len(df_fans))
df_fans.head(1)
# Out:
# ✅ Unique fans fetched: 22
#                                 PROFILE_ID  \
# 0  ACoAAB4hjd4BP4iUpWBPTB38bBy1QnuNYO2v6OQ
#
#                                          PROFILE_URL        PUBLIC_ID  \
# 0  https://www.linkedin.com/in/ACoAAB4hjd4BP4iUpW...  james-g-mallett
#
#   FIRSTNAME LASTNAME       FULLNAME             OCCUPATION REACTION  \
# 0     James  Mallett  James Mallett  Co-Founder at Beeline    LIKES
#
#           TEXT                                              TITLE  \
# 0  Not defined  📧 If you are using Sendinblue for your email c...
#
#              PUBLISHED_DATE      AUTHOR_NAME  \
# 0  2022-07-11 15:29:09+0200  Florent Ravenel
#
#                                             POST_URL         DATE_EXTRACT  \
# 0  https://www.linkedin.com/feed/update/urn:li:ac...  2022-07-12 14:06:33
#
#   SCENARIO
# 0  2022-07

# %% [markdown]
# ## Output

# %% [markdown]
# ### Update Notion Report

# %%
page = list_new_fans(KPI_TITLE,
                     PLATFORM,
                     OWNER,
                     df_engagements,
                     df_fans)
page
# Out:
# ✅ Page 'New fans - LinkedIn - Florent Ravenel' updated in Notion.
